# %% [markdown]
# ## Transform
# This notebook contains a set NYC datasets taken from OpenNYC (https://opendata.cityofnewyork.us/), New York's Open Data Portal. For each dataset
# - Read in the data
# - Inspect the data looking for any issues
# - Construct Python code to answer the accompanying questions

# %% [markdown]
# ## NYPD Demographics
# - How many rows and columns are in this data?
# - What are the variable types of each column?
# - Are any columns missing values?
# - What % of NYPD employees are female?
# - How is Gender different from sex?
# - What are the mean, median and mode number of years on job?
# - Now, examine Gender distribution by Rank?
# - Now, examine Race distribution by Rank?
#
# Source: https://data.cityofnewyork.us/Public-Safety/NYPD-Personnel-Demographics/5vr7-5fki/about_data

# %%
import pandas as pd
nypd = pd.read_csv('nypd_demographics.csv')
nypd.head()
# Out:
#   Gender      Race MOS_Type         ranklit   sex     appdate  YearsOnJob  \
# 0   Male  Hispanic  Uniform  Police Officer  Male  12/17/2025           0
# 1   Male  Hispanic  Uniform  Police Officer  Male  12/17/2025           0
# 2   Male  Hispanic  Uniform  Police Officer  Male  12/17/2025           0
# 3   Male  Hispanic  Uniform  Police Officer  Male  12/17/2025           0
# 4   Male  Hispanic  Uniform  Police Officer  Male  12/17/2025           0
#
#    YearsOnJob (bins)
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# ## New York Payroll
# NYC Payroll Data of those who had a Base Salary greater than $100,000 in 2025.
# https://data.cityofnewyork.us/City-Government/Citywide-Payroll-Data-Fiscal-Year-/k397-673e/explore/query/SELECT%0A%20%20%60fiscal_year%60%2C%0A%20%20%60payroll_number%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60last_name%60%2C%0A%20%20%60first_name%60%2C%0A%20%20%60mid_init%60%2C%0A%20%20%60agency_start_date%60%2C%0A%20%20%60work_location_borough%60%2C%0A%20%20%60title_description%60%2C%0A%20%20%60leave_status_as_of_june_30%60%2C%0A%20%20%60base_salary%60%2C%0A%20%20%60pay_basis%60%2C%0A%20%20%60regular_hours%60%2C%0A%20%20%60regular_gross_paid%60%2C%0A%20%20%60ot_hours%60%2C%0A%20%20%60total_ot_paid%60%2C%0A%20%20%60total_other_pay%60%0AWHERE%20%60fiscal_year%60%20IN%20%28%222025%22%29%20AND%20%28%60base_salary%60%20%3E%20200000%29%0AORDER%20BY%20%60agency_name%60%20ASC%20NULL%20LAST%2C%20%60fiscal_year%60%20DESC%20NULL%20FIRST/page/filter
#
#
# - Who are the top 10 earners?
# - Which agency pays the most?
# - How much does someone with "Data" in their Title earn?
# - How many Machine Learning Engineers are employed (and earn more than 100K)?

# %%
payroll = pd.read_csv('nyc_payroll_200k_plus.csv')
#payroll = pd.read_csv('nyc_payroll_100k_plus.csv')
payroll.head()
# Out:
#    Fiscal Year  Payroll Number                Agency Name Last Name  \
# 0         2025              67  ADMIN FOR CHILDREN'S SVCS     WADDY
# 1         2025              67  ADMIN FOR CHILDREN'S SVCS    KRAUSS
# 2         2025              67  ADMIN FOR CHILDREN'S SVCS    NEIDIG
# 3         2025              67  ADMIN FOR CHILDREN'S SVCS     WHITE
# 4         2025              67  ADMIN FOR CHILDREN'S SVCS  FREEDMAN
#
#   First Name Mid Init Agency Start Date Work Location Borough  \
# 0     WALTIA        S        01/03/2012             MANHATTAN
# 1       JILL        A        02/06/2012             MANHATTAN
# 2     JUSTIN        M        11/26/2012             MANHATTAN
# 3     ANDREW        K        06/23/2014             MANHATTAN
# 4       NEIL        S        12/08/2014             MANHATTAN
#
#                             Title Description Leave Status as of June 30  \
# 0  ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES                     ACTIVE
# ...

# %% [markdown]
# ## Baby Names
#
# - Which is the most common baby name?
# - Compare by gender.
# - Compare by ethnicity.
# - Trend over time.
#
# https://data.cityofnewyork.us/Health/Popular-Baby-Names/25th-nujf/about_data

# %%
baby = pd.read_csv('nyc_babies.csv', skiprows = 1, names= ['year','gender','ethnicity','name','count','rank'])
baby.head()
# Out:
#    year  gender                   ethnicity    name  count  rank
# 0  2021  FEMALE  ASIAN AND PACIFIC ISLANDER  Olivia     71     1
# 1  2021  FEMALE  ASIAN AND PACIFIC ISLANDER   Chloe     71     1
# 2  2021  FEMALE  ASIAN AND PACIFIC ISLANDER    Emma     66     2
# 3  2021  FEMALE  ASIAN AND PACIFIC ISLANDER     Mia     59     3
# 4  2021  FEMALE  ASIAN AND PACIFIC ISLANDER     Ava     53     4

# %%
#import seaborn as sns
#sns.lineplot(data = baby.loc[baby.name.isin(['Emma','Olivia','Sophia']),:], x = 'year', y = 'count', hue = 'name',errorbar = None );

# %% [markdown]
# ## NYC Dog Licensing
# Which is the most popular dog breed? May have make names consistent
# Most popular dog names?
# Median age when a dog is issued a license?
#
# Source: https://data.cityofnewyork.us/Health/NYC-Dog-Licensing-Dataset/nu7n-tubp/about_data

# %%
import pandas as pd
dogs = pd.read_csv('dog_licenses.csv', parse_dates=['LicenseIssuedDate','LicenseExpiredDate'] )
dogs.head()
#dogs.AnimalBirthYear = pd.to_datetime(dogs.AnimalBirthYear,format = '%Y', errors = 'coerce')
#dogs.AnimalBirthYear.dt.year
# Out:
# C:\Users\vlala\AppData\Local\Temp\ipykernel_23876\130868812.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   dogs = pd.read_csv('dog_licenses.csv', parse_dates=['LicenseIssuedDate','LicenseExpiredDate'] )
# BreedName
# Unknown                        63558
# Yorkshire Terrier              40224
# Shih Tzu                       37108
# Chihuahua                      28086
# Labrador Retriever             21852
#                                ...
# Pinscher Mix                       1
# Mixed breed                        1
# YORKER/JACKRUSELL/CHIHUAHUA        1
# DACHSHUND   X                      1
# FOX TER/C.SPAN                     1
# Name: count, Length: 1595, dtype: int64

# %% [markdown]
# ## Wifi Hotspots
#
# - Which borough has the most Wi-Fi hotspots?
# - Which provider operates the most hotspots?
# - Are hotspots mostly outdoor, subway, library, or public-space locations?
# - Which ZIP codes have the most hotspots?
# - How many hotspots are free versus limited free?
#
#
#
# Source: https://data.cityofnewyork.us/City-Government/NYC-Wi-Fi-Hotspot-Locations/yjub-udmw/about_data

# %%
wifi = pd.read_csv('wifi.csv')
wifi.head()
# Out:
#    OBJECTID  Borough          Type           Provider                    Name  \
# 0     10604        4  Limited Free           SPECTRUM       Baisley Pond Park
# 1     10555        4  Limited Free           SPECTRUM            Kissena Park
# 2     12370        3          Free   Transit Wireless            Grand St (L)
# 3      9893        3          Free  Downtown Brooklyn                     NaN
# 4     10169        1          Free   Transit Wireless  Lexington Av-63 St (F)
#
#                  Location   Latitude  Longitude                X  \
# 0          Park Perimeter  40.674860 -73.784120  1,044,131.89696
# 1          Park Perimeter  40.747560 -73.818150  1,034,637.51076
# 2            Grand St (L)  40.711926 -73.940670  1,000,698.12752
# 3           125 Court St.  40.689985 -73.991995   986,469.966349
# 4  Lexington Av-63 St (F)  40.764630 -73.966115   993,636.552081
#
#                 Y  ... Neighborhood Tabulation Area (NTA) Council Distrcit  \
# ...

# %% [markdown]
# ### NYC Restaurants
# Department of Health data on New York restaurant inspections recorded between Jan 1, 2025 and June 10, 2026
#
# - What are the most common cuisine types in NYC?
# - Which borough has the most restaurants in the dataset?
# - What is the distribution of inspection scores?
# - Which cuisine types have the highest average inspection scores?
# - How many restaurants receive A, B, or C grades?
# - What are the most common violation types?
#
# Source: https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j/about_data

# %%
restaurants = pd.read_csv('restaurants_jan_jun_2026.csv')
restaurants.head()
# Out:
#       CAMIS                      DBA       BORO BUILDING            STREET  \
# 0  50177166  CARIBBEAN FLAME CUISINE     Queens   126-08        111 AVENUE
# 1  50090528               16 HANDLES  Manhattan      428          3 AVENUE
# 2  50148121           OLD SPORT FOOD     Queens    67-03     AUSTIN STREET
# 3  41640282                 GYU-KAKU  Manhattan      321  WEST   44 STREET
# 4  50167382            EXPRESS MANTI   Brooklyn     1013          AVENUE H
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11420.0  3479897451           Caribbean      04/16/2026
# 1  10016.0  2122131755     Frozen Desserts      04/30/2026
# 2  11375.0  9292960009             Chinese      04/23/2026
# 3  10036.0  6466929115            Japanese      04/27/2026
# 4  11230.0  3479253178    Eastern European      01/21/2026
#
#                                               ACTION  ...  \
# 0                  Establishment re-opened by DOHMH.  ...
# ...
