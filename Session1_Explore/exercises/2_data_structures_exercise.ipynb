# %% [markdown]
# ## In-Class Exercise: Data Structures
#
# This exercise will help you practice using tuples, dictionaries, and lists in Python. Complete the tasks in the empty code cells provided.

# %% [markdown]
# ### 1) Tuples
# **Question:**
# A. Create a tuple `fruits = ("apple", "banana", "cherry")`.
# B. Print the first element of the tuple.

# %%
# A. Create tuple


# B. Print first element

# %% [markdown]
# ### 2) Dictionaries
# **Question:**
# A. Create a dictionary `student = {"name": "Sam", "age": 21, "major": "Math"}`.
# B. Access the value for the key `'major'`.

# %%
# A. Create dictionary


# B. Access value for 'major'

# %% [markdown]
# ### 3) Lists – Creation & Indexing
# **Question:**
# A. Create a list `nums = [3, 6, 9, 12, 15]`.
# B. Print the first and last items from the list.

# %%
# A. Create list


# B. First and last items

# %% [markdown]
# ### 4) Lists – Slicing
# Given `letters = ["a", "b", "c", "d", "e", "f"]`:
# A. Slice the first four elements.
# B. Slice from the 3rd element to the end.

# %%
# A. First four


# B. From 3rd to end

# %% [markdown]
# ### 5) Lists – Methods
# Start with `colors = ["red", "blue", "green"]`:
# A. Append `'yellow'` to the list.
# B. Remove `'blue'`.
# C. Check if `'purple'` is in the list.

# %%
# A. Append


# B. Remove


# C. Membership test
