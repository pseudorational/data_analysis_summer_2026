# %% [markdown]
# ## Exercise: Pandas
#
# This exercise will help you practice creating and exploring Pandas Series and DataFrames.
#
# Fill in the code cells with your answers.

# %% [markdown]
# ### 1) Series from a List
# **Question:**
# A. Create a Pandas Series from the list `[10, 20, 30, 40, 50]`.
# B. Print the Series.

# %%
# A. Create Series from list


# B. Print

# %% [markdown]
# ### 2) Series from a Dictionary
# **Question:**
# A. Create a dictionary with student ages: `{"Alice": 20, "Bob": 22, "Charlie": 19}`.
# B. Convert it into a Pandas Series.
# C. Access the age of `"Bob"`.

# %%
# A. Dictionary


# B. Series from dictionary


# C. Access Bob

# %% [markdown]
# ### 3) Series Methods
# **Question:**
# Given `scores = pd.Series([90, 85, 88, 92, 76])`:
# A. Find the mean.
# B. Find the standard deviation.
# C. Find the sum.

# %%
import pandas as pd
scores = pd.Series([90, 85, 88, 92, 76])
# A. Mean


# B. Standard deviation


# C. Sum

# %% [markdown]
# ### 4) Series Attributes
# Using the `scores` Series above:
# A. Print its `dtype`.
# B. Print its `size`.
# C. Check if all values are unique.

# %%
# A. dtype


# B. size


# C. is_unique

# %% [markdown]
# ### 5) DataFrame from a Dictionary
# **Question:**
# A. Create a DataFrame with keys: `"name"`, `"age"`, `"city"`. Use at least 3 rows of data.
# B. Display the `.info()` of the DataFrame.
# C. Print the shape of the DataFrame.

# %%
# A. Create DataFrame


# B. info()


# C. shape
