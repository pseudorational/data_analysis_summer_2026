# %% [markdown]
# ## In-Class Exercise: Basics
#
# This exercise will help you practice arithmetic, variables, strings, types, and casting. Answer each question in the provided code boxes.

# %% [markdown]
# ### 1) Arithmetic Expressions
# **Question:**
#
# A. Evaluate the following two expressions and explain why they give different results:
# ```python
# 250 * 12 + 50
# 250 * (12 + 50)
# ```
# B. Write your own arithmetic expression with at least three numbers and parentheses.

# %%
# A. Evaluate and explain



# B. Your expression

# %% [markdown]
# ### 2) Variables and Assignment
# ```python
# x = 18
# y = 27
# x * y
# # 100 = z   # This will cause an error
# ```
# **Question:**
# A. Why does `100 = z` cause an error?
# B. Multiply `x` and `y` and store the result in a new variable called `product`.

# %%
# A. Explanation as comment



# B. Correct code

# %% [markdown]
# ### 3) Updating Variables
# **Question:**
# A. Start with `counter = 10`. Increase its value by 1 using the long form (`counter = counter + 1`).
# B. Now increase it again using the shorthand form (`+=`).

# %%
# A. Long form



# B. Shorthand form

# %% [markdown]
# ### 4) Strings and Numbers
# ```python
# age = 20
# name = "Alice"
# ```
# **Question:**
# A. Create a variable `age_next_year` that stores Alice’s age next year.
# B. Print the sentence: `"Alice will be 21 next year"` using an f-string.

# %%
# A. Calculate age_next_year



# B. f-string

# %% [markdown]
# ### 5) Data Types
# **Question:**
# A. Check the type of `99` and `99.9`.
# B. Why does `isinstance(9/2, float)` return `True`?
# C. Write code to check if `True` is a boolean.

# %%
# A. Types



# B. Explanation as comment



# C. isinstance(True, bool)

# %% [markdown]
# ### 6) Strings and Concatenation
# **Question:**
# A. Concatenate the words `"Machine"` and `"Learning"` with a space in between.
# B. Use an f-string with variables `tech = "Python"` and `feature = "dynamic"` to print `"Python is dynamic"`.

# %%
# A. Concatenate



# B. f-string

# %% [markdown]
# ### 7) String Encoding
# ```python
# snack = "Crème brûlée"
# ```
# **Question:**
# A. Encode `snack` into UTF-8.
# B. Check the type of the encoded object.
# C. Decode it back to a normal string.

# %%
# A. Encode


# B. Type check


# C. Decode

# %% [markdown]
# ### 8) Comparisons
# **Question:**
# A. Compare two strings `"zebra"` and `"apple"`. Which one is greater? Why?
# B. Compare the numbers `42` and `17`.

# %%
# A. Compare strings



# B. Compare numbers

# %% [markdown]
# ### 9) None
# **Question:**
# A. Create a variable `data` and assign it `None`.
# B. Check if `data is None`.
# C. Reassign `data = 500` and check again.

# %%
# A. Assign None


# B. Check None


# C. Reassign and check again
# Out:
# False

# %% [markdown]
# ### 10) Type Casting
# **Question:**
# A. Convert the number `123` into a string, a float, and a boolean.
# B. Why does `bool(0)` return `False` but `bool(123)` return `True`?

# %%
# A. Conversions



# B. Explanation
