# %% [markdown]
# ## Exercise: NumPy
#
# This exercise will help you practice creating arrays, using array generators, random numbers, array properties, and broadcasting in NumPy.

# %% [markdown]
# ### 1) Creating Arrays
# **Question:**
# A. Create a 1D NumPy array with values `[2, 4, 6, 8, 10]`.
# B. Create a 2D array `[[1, 2, 3], [4, 5, 6]]`.
# C. Check the type of the object.

# %%
# A. 1D array



# B. 2D array



# C. Type

# %% [markdown]
# ### 2) Array Generators
# **Question:**
# A. Create a `3x3` array of ones.
# B. Create an array of 15 evenly spaced values between 0 and 5.
# C. Create an array of even numbers from 2 to 20 using `arange()`.

# %%
# A. ones



# B. linspace



# C. arange

# %% [markdown]
# ### 3) Random Numbers
# **Question:**
# A. Generate a `2x2` array of random numbers between 0 and 1.
# B. Generate 5 random integers between 10 and 50.
# C. Generate 8 random values from a normal distribution (mean = 0, std = 1).

# %%
# A. random



# B. randint



# C. normal

# %% [markdown]
# ### 4) Array Properties
# **Question:**
# A. Create an array with numbers 1 through 12.
# B. Reshape it into a `3x4` array.
# C. Flatten it back to 1D.
# D. Print its shape and size.

# %%
# A. Create array



# B. Reshape



# C. Flatten



# D. Shape and size

# %% [markdown]
# ### 5) Arithmetic and Broadcasting
# **Question:**
# A. Create two arrays: `x = np.array([1,2,3])` and `y = np.array([10,20,30])`. Perform elementwise addition and multiplication.
# B. Square every element of `x`.
# C. Create a 2D array `[[1,2,3],[4,5,6]]` and add the 1D array `[10,20,30]` using broadcasting.

# %%
# A. Addition & multiplication



# B. Square elements



# C. Broadcasting
